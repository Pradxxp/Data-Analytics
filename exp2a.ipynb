# %%
# Step 1: Importing the required Libraries
import pandas as pd
import numpy as np
# Pandas is used to import and manage the data sets.

# %%
dataset = pd.read_csv('/content/exp2.csv')

# %%
dataset
# Out:
#    Application_No State     Medium   Age    Income  Cgpa Eligible
# 0               1    TN    English  21.0  700000.0   8.1      Yes
# 1               2    KL  Malayalam  23.0  750000.0   9.3       No
# 2               3    KL    English   NaN  400000.0   7.9       No
# 3               4    KA    English  24.0       NaN   6.4      Yes
# 4               5    KA        NaN  20.0  500000.0   9.0      Yes
# 5               6    TN      Tamil  22.0  560000.0   NaN      Yes
# 6               7    TN    English  23.0  300000.0   7.6       No
# 7               8    KL    English   NaN  900000.0   8.7      Yes
# 8               9    TN      Tamil  21.0  780000.0   8.4      Yes
# 9              10    TN    English  25.0  340000.0   7.5      Yes

# %%
print(dataset.shape)
# Out:
# (10, 7)

# %%
print(dataset.isnull().sum())
# Out:
# Application_No    0
# State             0
# Medium            1
# Age               2
# Income            1
# Cgpa              1
# Eligible          0
# dtype: int64

# %%
numeric_dataset = dataset.select_dtypes(include=['number'])

# %%
dataset[numeric_dataset.columns] = numeric_dataset.fillna(numeric_dataset.median(), inplace=False)

# %%
features=['Application_No','State','Medium','Age','Income','Cgpa']
target=['Eligible']

# %%
X = dataset.loc[:, features]
y = dataset.loc[:, target]

# %%
print(X)
# Out:
#    Application_No State     Medium   Age    Income  Cgpa
# 0               1    TN    English  21.0  700000.0   8.1
# 1               2    KL  Malayalam  23.0  750000.0   9.3
# 2               3    KL    English  22.5  400000.0   7.9
# 3               4    KA    English  24.0  560000.0   6.4
# 4               5    KA        NaN  20.0  500000.0   9.0
# 5               6    TN      Tamil  22.0  560000.0   8.1
# 6               7    TN    English  23.0  300000.0   7.6
# 7               8    KL    English  22.5  900000.0   8.7
# 8               9    TN      Tamil  21.0  780000.0   8.4
# 9              10    TN    English  25.0  340000.0   7.5

# %%
print(y)
# Out:
#   Eligible
# 0      Yes
# 1       No
# 2       No
# 3      Yes
# 4      Yes
# 5      Yes
# 6       No
# 7      Yes
# 8      Yes
# 9      Yes

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
dataset['Encoded_state'] = encoder.fit_transform(dataset['State'])

# %%
dataset
# Out:
#    Application_No State     Medium   Age    Income  Cgpa Eligible  \
# 0               1    TN    English  21.0  700000.0   8.1      Yes
# 1               2    KL  Malayalam  23.0  750000.0   9.3       No
# 2               3    KL    English  22.5  400000.0   7.9       No
# 3               4    KA    English  24.0  560000.0   6.4      Yes
# 4               5    KA        NaN  20.0  500000.0   9.0      Yes
# 5               6    TN      Tamil  22.0  560000.0   8.1      Yes
# 6               7    TN    English  23.0  300000.0   7.6       No
# 7               8    KL    English  22.5  900000.0   8.7      Yes
# 8               9    TN      Tamil  21.0  780000.0   8.4      Yes
# 9              10    TN    English  25.0  340000.0   7.5      Yes
#
#    Encoded_state
# 0              2
# 1              1
# 2              1
# 3              0
# 4              0
# 5              2
# 6              2
# 7              1
# 8              2
# 9              2

# %%
dataset['binned_age'] = pd.cut(
dataset['Age'],
bins=3,
labels=['Middle-aged', 'old-aged', 'Young-aged'])

# %%
dataset
# Out:
#    Application_No State     Medium   Age    Income  Cgpa Eligible  \
# 0               1    TN    English  21.0  700000.0   8.1      Yes
# 1               2    KL  Malayalam  23.0  750000.0   9.3       No
# 2               3    KL    English  22.5  400000.0   7.9       No
# 3               4    KA    English  24.0  560000.0   6.4      Yes
# 4               5    KA        NaN  20.0  500000.0   9.0      Yes
# 5               6    TN      Tamil  22.0  560000.0   8.1      Yes
# 6               7    TN    English  23.0  300000.0   7.6       No
# 7               8    KL    English  22.5  900000.0   8.7      Yes
# 8               9    TN      Tamil  21.0  780000.0   8.4      Yes
# 9              10    TN    English  25.0  340000.0   7.5      Yes
#
#    Encoded_state   binned_age
# 0              2  Middle-aged
# 1              1     old-aged
# 2              1     old-aged
# 3              0   Young-aged
# 4              0  Middle-aged
# 5              2     old-aged
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
dataset['Scaled_cgpa'] = scaler.fit_transform(dataset[['Cgpa']])

# %%
dataset
# Out:
#    Application_No State     Medium   Age    Income  Cgpa Eligible  \
# 0               1    TN    English  21.0  700000.0   8.1      Yes
# 1               2    KL  Malayalam  23.0  750000.0   9.3       No
# 2               3    KL    English  22.5  400000.0   7.9       No
# 3               4    KA    English  24.0  560000.0   6.4      Yes
# 4               5    KA        NaN  20.0  500000.0   9.0      Yes
# 5               6    TN      Tamil  22.0  560000.0   8.1      Yes
# 6               7    TN    English  23.0  300000.0   7.6       No
# 7               8    KL    English  22.5  900000.0   8.7      Yes
# 8               9    TN      Tamil  21.0  780000.0   8.4      Yes
# 9              10    TN    English  25.0  340000.0   7.5      Yes
#
#    Encoded_state   binned_age  Scaled_cgpa
# 0              2  Middle-aged     0.586207
# 1              1     old-aged     1.000000
# 2              1     old-aged     0.517241
# 3              0   Young-aged     0.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
dataset['standardized_cgpa'] = scaler.fit_transform(dataset[['Cgpa']])

# %%
dataset
# Out:
#    Application_No State     Medium   Age    Income  Cgpa Eligible  \
# 0               1    TN    English  21.0  700000.0   8.1      Yes
# 1               2    KL  Malayalam  23.0  750000.0   9.3       No
# 2               3    KL    English  22.5  400000.0   7.9       No
# 3               4    KA    English  24.0  560000.0   6.4      Yes
# 4               5    KA        NaN  20.0  500000.0   9.0      Yes
# 5               6    TN      Tamil  22.0  560000.0   8.1      Yes
# 6               7    TN    English  23.0  300000.0   7.6       No
# 7               8    KL    English  22.5  900000.0   8.7      Yes
# 8               9    TN      Tamil  21.0  780000.0   8.4      Yes
# 9              10    TN    English  25.0  340000.0   7.5      Yes
#
#    Encoded_state   binned_age  Scaled_cgpa  standardized_cgpa
# 0              2  Middle-aged     0.586207           0.000000
# 1              1     old-aged     1.000000           1.519109
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size = .75)

# %%
X_train
# Out:
#    Application_No State     Medium   Age    Income  Cgpa
# 9              10    TN    English  25.0  340000.0   7.5
# 1               2    KL  Malayalam  23.0  750000.0   9.3
# 6               7    TN    English  23.0  300000.0   7.6
# 7               8    KL    English  22.5  900000.0   8.7
# 3               4    KA    English  24.0  560000.0   6.4
# 0               1    TN    English  21.0  700000.0   8.1
# 5               6    TN      Tamil  22.0  560000.0   8.1

# %%
X_test
# Out:
#    Application_No State   Medium   Age    Income  Cgpa
# 2               3    KL  English  22.5  400000.0   7.9
# 8               9    TN    Tamil  21.0  780000.0   8.4
# 4               5    KA      NaN  20.0  500000.0   9.0

# %%
y_train
# Out:
#   Eligible
# 9      Yes
# 1       No
# 6       No
# 7      Yes
# 3      Yes
# 0      Yes
# 5      Yes

# %%
y_test
# Out:
#   Eligible
# 2       No
# 8      Yes
# 4      Yes

# %%
print(dataset.isnull().sum())
# Out:
# Application_No       0
# State                0
# Medium               1
# Age                  0
# Income               0
# Cgpa                 0
# Eligible             0
# Encoded_state        0
# binned_age           0
# Scaled_cgpa          0
# standardized_cgpa    0
# dtype: int64

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import LabelEncoder

# Verify if 'State' column exists, if not, adjust accordingly
print(X_train.columns)  # Check column names in X_train
print(X_test.columns)   # Check column names in X_test

# Assuming the column is named 'state' (lowercase)
X_train = pd.get_dummies(X_train, columns=['State'])
X_test = pd.get_dummies(X_test, columns=['State'])

# Align columns in X_train and X_test after one-hot encoding
X_train, X_test = X_train.align(X_test, join='outer', axis=1, fill_value=0)

le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train, y_train)
score = regressor.score(X_test, y_test)
print(score)
# Out:
# Index(['Application_No', 'Medium', 'Age', 'Income', 'Cgpa', 'State_KA',
#        'State_KL', 'State_TN'],
#       dtype='object')
# Index(['Application_No', 'Medium', 'Age', 'Income', 'Cgpa', 'State_KA',
#        'State_KL', 'State_TN'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-72a985bfaf33> in <cell line: 10>()
#       8
#       9 # Assuming the column is named 'state' (lowercase)
# ---> 10 X_train = pd.get_dummies(X_train, columns=['State'])
#      11 X_test = pd.get_dummies(X_test, columns=['State'])
#      12
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     162             raise TypeError("Input must be a list-like for parameter `columns`")
#     163         else:
# ...
